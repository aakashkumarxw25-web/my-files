# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **SpaceX  Falcon 9 first stage Landing Prediction**

# %% [markdown]
# # Hands-on Lab: Complete the Data Collection API Lab

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# In this capstone, we will predict if the Falcon 9 first stage will land successfully. SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars; other providers cost upward of 165 million dollars each, much of the savings is because SpaceX can reuse the first stage. Therefore if we can determine if the first stage will land, we can determine the cost of a launch. This information can be used if an alternate company wants to bid against SpaceX for a rocket launch. In this lab, you will collect and make sure the data is in the correct format from an API. The following is an example of a successful and launch.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/lab_v2/images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/lab_v2/images/crash.gif)

# %% [markdown]
# Most unsuccessful landings are planned. Space X performs a controlled landing in the oceans.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will make a get request to the SpaceX API. You will also do some basic data wrangling and formating.
#
# - Request to the SpaceX API
# - Clean the requested data

# %% [markdown]
# ----

# %% [markdown]
# Install the below libraries

# %%
# !pip install requests
# !pip install pandas
# !pip install numpy
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.6.17)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %% [markdown]
# ## Import Libraries and Define Auxiliary Functions

# %% [markdown]
# We will import the following libraries into the lab

# %%
# Requests allows us to make HTTP requests which we will use to get data from an API
import requests
# Pandas is a software library written for the Python programming language for data manipulation and analysis.
import pandas as pd
# NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
import numpy as np
# Datetime is a library that allows us to represent dates
import datetime

# Setting this option will print all collumns of a dataframe
pd.set_option('display.max_columns', None)
# Setting this option will print all of the data in a feature
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Below we will define a series of helper functions that will help us use the API to extract information using identification numbers in the launch data.
#
# From the <code>rocket</code> column we would like to learn the booster name.

# %%
# Takes the dataset and uses the rocket column to call the API and append the data to the list
def getBoosterVersion(data):
    for x in data['rocket']:
       if x:
        response = requests.get("https://api.spacexdata.com/v4/rockets/"+str(x)).json()
        BoosterVersion.append(response['name'])

# %% [markdown]
# From the <code>launchpad</code> we would like to know the name of the launch site being used, the logitude, and the latitude.

# %%
# Takes the dataset and uses the launchpad column to call the API and append the data to the list
def getLaunchSite(data):
    for x in data['launchpad']:
       if x:
         response = requests.get("https://api.spacexdata.com/v4/launchpads/"+str(x)).json()
         Longitude.append(response['longitude'])
         Latitude.append(response['latitude'])
         LaunchSite.append(response['name'])

# %% [markdown]
# From the <code>payload</code> we would like to learn the mass of the payload and the orbit that it is going to.

# %%
# Takes the dataset and uses the payloads column to call the API and append the data to the lists
def getPayloadData(data):
    for load in data['payloads']:
       if load:
        response = requests.get("https://api.spacexdata.com/v4/payloads/"+load).json()
        PayloadMass.append(response['mass_kg'])
        Orbit.append(response['orbit'])

# %% [markdown]
# From <code>cores</code> we would like to learn the outcome of the landing, the type of the landing, number of flights with that core, whether gridfins were used, wheter the core is reused, wheter legs were used, the landing pad used, the block of the core which is a number used to seperate version of cores, the number of times this specific core has been reused, and the serial of the core.

# %%
# Takes the dataset and uses the cores column to call the API and append the data to the lists
def getCoreData(data):
    for core in data['cores']:
            if core['core'] != None:
                response = requests.get("https://api.spacexdata.com/v4/cores/"+core['core']).json()
                Block.append(response['block'])
                ReusedCount.append(response['reuse_count'])
                Serial.append(response['serial'])
            else:
                Block.append(None)
                ReusedCount.append(None)
                Serial.append(None)
            Outcome.append(str(core['landing_success'])+' '+str(core['landing_type']))
            Flights.append(core['flight'])
            GridFins.append(core['gridfins'])
            Reused.append(core['reused'])
            Legs.append(core['legs'])
            LandingPad.append(core['landpad'])

# %% [markdown]
# Now let's start requesting rocket launch data from SpaceX API with the following URL:

# %%
spacex_url="https://api.spacexdata.com/v4/launches/past"

# %%
response = requests.get(spacex_url)

# %% [markdown]
# Check the content of the response

# %%
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->\n<head>\n\n<title>spacexdata.com | 525: SSL handshake failed</title>\n<meta charset="UTF-8" />\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n<meta name="robots" content="noindex, nofollow" />\n<meta name="viewport" content="width=device-width,initial-scale=1" />\n<link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />\n</head>\n<body>\n<div id="cf-wrapper">\n    <div id="cf-error-details" class="p-0">\n        <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">\n            <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">\n                <span class="inline-block">SSL handshake failed</span>\n                <span class="code-label">Error code 525</span>\n            </h1>\n            <div>\n                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_525&utm_campaign=api.spacexdata.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.\n            </div>\n            <div class="mt-3">2026-07-21 23:27:29 UTC</div>\n        </header>\n        <div class="my-8 bg-gradient-gray">\n            <div class="w-240 lg:w-full mx-auto">\n                <div class="clearfix md:px-8">\n                    <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">\n  <div class="relative mb-10 md:m-0">\n    \n    <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>\n    <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>\n    \n  </div>\n  <span class="md:block w-full truncate">You</span>\n  <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">\n  \n    Browser\n  \n  </h3>\n  \n  <span class="leading-1.3 text-2xl text-green-success">Working</span>\n  \n</div>\n                    <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">\n  <div class="relative mb-10 md:m-0">\n    <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_525&#38;utm_campaign=api.spacexdata.com" target="_blank" rel="noopener noreferrer">\n    <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>\n    <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>\n    </a>\n  </div>\n  <span class="md:block w-full truncate">Atlanta</span>\n  <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">\n  <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_525&utm_campaign=api.spacexdata.com" target="_blank" rel="noopener noreferrer">\n    Cloudflare\n  </a>\n  </h3>\n  \n  <span class="leading-1.3 text-2xl text-green-success">Working</span>\n  \n</div>\n                    <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">\n  <div class="relative mb-10 md:m-0">\n    \n    <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>\n    <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>\n    \ ...

# %% [markdown]
# You should see the response contains massive information about SpaceX launches. Next, let's try to discover some more relevant information for this project.

# %% [markdown]
# ### Task 1: Request and parse the SpaceX launch data using the GET request

# %% [markdown]
# To make the requested JSON results more consistent, we will use the following static response object for this project:

# %%
static_json_url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/API_call_spacex_api.json'

# %% [markdown]
# We should see that the request was successfull with the 200 status response code

# %%
response.status_code
# Out:
# 525

# %% [markdown]
# Now we decode the response content as a Json using <code>.json()</code> and turn it into a Pandas dataframe using <code>.json_normalize()</code>

# %%
response = requests.get(static_json_url)
data = pd.json_normalize(response.json())

# %% [markdown]
# Using the dataframe <code>data</code> print the first 5 rows

# %%
# Get the head of the dataframe

# %% [markdown]
# You will notice that a lot of the data are IDs. For example the rocket column has no information about the rocket just an identification number.
#
# We will now use the API again to get information about the launches using the IDs given for each launch. Specifically we will be using columns <code>rocket</code>, <code>payloads</code>, <code>launchpad</code>, and <code>cores</code>.

# %%
# Lets take a subset of our dataframe keeping only the features we want and the flight number, and date_utc.
data = data[['rocket', 'payloads', 'launchpad', 'cores', 'flight_number', 'date_utc']]

# We will remove rows with multiple cores because those are falcon rockets with 2 extra rocket boosters and rows that have multiple payloads in a single rocket.
data = data[data['cores'].map(len)==1]
data = data[data['payloads'].map(len)==1]

# Since payloads and cores are lists of size 1 we will also extract the single value in the list and replace the feature.
data['cores'] = data['cores'].map(lambda x : x[0])
data['payloads'] = data['payloads'].map(lambda x : x[0])

# We also want to convert the date_utc to a datetime datatype and then extracting the date leaving the time
data['date'] = pd.to_datetime(data['date_utc']).dt.date

# Using the date we will restrict the dates of the launches
data = data[data['date'] <= datetime.date(2020, 11, 13)]

# %% [markdown]
# * From the <code>rocket</code> we would like to learn the booster name
#
# * From the <code>payload</code> we would like to learn the mass of the payload and the orbit that it is going to
#
# * From the <code>launchpad</code> we would like to know the name of the launch site being used, the longitude, and the latitude.
#
# * **From <code>cores</code> we would like to learn the outcome of the landing, the type of the landing, number of flights with that core, whether gridfins were used, whether the core is reused, whether legs were used, the landing pad used, the block of the core which is a number used to seperate version of cores, the number of times this specific core has been reused, and the serial of the core.**
#
# The data from these requests will be stored in lists and will be used to create a new dataframe.

# %%
#Global variables
BoosterVersion = []
PayloadMass = []
Orbit = []
LaunchSite = []
Outcome = []
Flights = []
GridFins = []
Reused = []
Legs = []
LandingPad = []
Block = []
ReusedCount = []
Serial = []
Longitude = []
Latitude = []

# %% [markdown]
# These functions will apply the outputs globally to the above variables. Let's take a looks at <code>BoosterVersion</code> variable. Before we apply  <code>getBoosterVersion</code> the list is empty:

# %%
BoosterVersion
# Out:
# []

# %% [markdown]
# Now, let's apply <code> getBoosterVersion</code> function method to get the booster version

# %%
# Call getBoosterVersion
def getBoosterVersion(data):
    for x in data['rocket']:
       if x:
        response = requests.get("https://api.spacexdata.com/v4/rockets/"+str(x))
        if response.status_code == 200:
            BoosterVersion.append(response.json()['name'])
        else:
            # Append None or handle the error appropriately if API call fails
            print(f"Error fetching rocket data for ID {x}: Status code {response.status_code}")
            BoosterVersion.append(None)
getBoosterVersion(data)
# Out:
# Error fetching rocket data for ID 5e9d0d95eda69955f709d1eb: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69955f709d1eb: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69955f709d1eb: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69955f709d1eb: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525
# Error fetching rocket data for ID 5e9d0d95eda69973a809d1ec: Status code 525

# %% [markdown]
# the list has now been update

# %%
BoosterVersion[0:5]
# Out:
# [None, None, None, None, None]

# %% [markdown]
# we can apply the rest of the  functions here:

# %%
# Call getLaunchSite
def getLaunchSite(data):
    for x in data['launchpad']:
       if x:
        response = requests.get("https://api.spacexdata.com/v4/launchpads/"+str(x))
        if response.status_code == 200:
            response_json = response.json()
            Longitude.append(response_json['longitude'])
            Latitude.append(response_json['latitude'])
            LaunchSite.append(response_json['name'])
        else:
            print(f"Error fetching launchpad data for ID {x}: Status code {response.status_code}")
            Longitude.append(None)
            Latitude.append(None)
            LaunchSite.append(None)
getLaunchSite(data)
# Out:
# Error fetching launchpad data for ID 5e9e4502f5090995de566f86: Status code 525
# Error fetching launchpad data for ID 5e9e4502f5090995de566f86: Status code 525
# Error fetching launchpad data for ID 5e9e4502f5090995de566f86: Status code 525
# Error fetching launchpad data for ID 5e9e4502f5090995de566f86: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509092b78566f87: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4502f509094188566f88: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525
# Error fetching launchpad data for ID 5e9e4501f509094ba4566f84: Status code 525

# %%
# Call getPayloadData
def getPayloadData(data):
    for load in data['payloads']:
       if load:
        response = requests.get("https://api.spacexdata.com/v4/payloads/"+load)
        if response.status_code == 200:
            response_json = response.json()
            PayloadMass.append(response_json['mass_kg'])
            Orbit.append(response_json['orbit'])
        else:
            print(f"Error fetching payload data for ID {load}: Status code {response.status_code}")
            PayloadMass.append(None)
            Orbit.append(None)
getPayloadData(data)
# Out:
# Error fetching payload data for ID 5eb0e4b5b6c3bb0006eeb1e1: Status code 525
# Error fetching payload data for ID 5eb0e4b6b6c3bb0006eeb1e2: Status code 525
# Error fetching payload data for ID 5eb0e4b7b6c3bb0006eeb1e5: Status code 525
# Error fetching payload data for ID 5eb0e4b7b6c3bb0006eeb1e6: Status code 525
# Error fetching payload data for ID 5eb0e4b7b6c3bb0006eeb1e7: Status code 525
# Error fetching payload data for ID 5eb0e4d1b6c3bb0006eeb256: Status code 525
# Error fetching payload data for ID 5eb0e4d1b6c3bb0006eeb258: Status code 525
# Error fetching payload data for ID 5eb0e4d2b6c3bb0006eeb25c: Status code 525
# Error fetching payload data for ID 5eb0e4d2b6c3bb0006eeb25b: Status code 525
# Error fetching payload data for ID 5ed9859f1f30554030d45c3f: Status code 525
# Error fetching payload data for ID 5eb0e4d1b6c3bb0006eeb259: Status code 525
# Error fetching payload data for ID 5ef6a4600059c33cee4a829e: Status code 525
# Error fetching payload data for ID 5ef6a48e0059c33cee4a829f: Status code 525
# Error fetching payload data for ID 5ef6a4d50059c33cee4a82a1: Status code 525
# Error fetching payload data for ID 5ef6a4ea0059c33cee4a82a2: Status code 525
# Error fetching payload data for ID 5eb0e4d2b6c3bb0006eeb25e: Status code 525

# %%
# Call getCoreData
def getCoreData(data):
    for core in data['cores']:
        if core and core['core']:
            response = requests.get("https://api.spacexdata.com/v4/cores/"+core['core'])
            if response.status_code == 200:
                response_json = response.json()
                Block.append(response_json['block'])
                ReusedCount.append(response_json['reuse_count'])
                Serial.append(response_json['serial'])
            else:
                print(f"Error fetching core data for ID {core['core']}: Status code {response.status_code}")
                Block.append(None)
                ReusedCount.append(None)
                Serial.append(None)
        else:
            Block.append(None)
            ReusedCount.append(None)
            Serial.append(None)
        # These fields are always available from the 'data' dataframe's 'cores' column
        Outcome.append(str(core['landing_success'])+' '+str(core['landing_type']))
        Flights.append(core['flight'])
        GridFins.append(core['gridfins'])
        Reused.append(core['reused'])
        Legs.append(core['legs'])
        LandingPad.append(core['landpad'])
getCoreData(data)
# Out:
# Error fetching core data for ID 5e9e289df35918033d3b2623: Status code 525
# Error fetching core data for ID 5e9e289ef35918416a3b2624: Status code 525
# Error fetching core data for ID 5e9e289ef3591855dc3b2626: Status code 525
# Error fetching core data for ID 5e9e289ef359184f103b2627: Status code 525
# Error fetching core data for ID 5e9e289ef359185f2b3b2628: Status code 525
# Error fetching core data for ID 5e9e289ef35918f39c3b262a: Status code 525
# Error fetching core data for ID 5e9e289ff3591884e03b262c: Status code 525
# Error fetching core data for ID 5e9e289ff359180ae23b262d: Status code 525
# Error fetching core data for ID 5e9e289ff35918862c3b262e: Status code 525
# Error fetching core data for ID 5e9e289ff3591878603b262f: Status code 525
# Error fetching core data for ID 5e9e289ff3591829343b2630: Status code 525
# Error fetching core data for ID 5e9e28a0f3591870a63b2631: Status code 525
# Error fetching core data for ID 5e9e28a0f359186e2e3b2632: Status code 525
# Error fetching core data for ID 5e9e28a0f35918b1bc3b2633: Status code 525
# Error fetching core data for ID 5e9e28a0f359184a683b2634: Status code 525
# Error fetching core data for ID 5e9e28a0f359187a3c3b2635: Status code 525
# Error fetching core data for ID 5e9e28a0f3591885be3b2636: Status code 525
# Error fetching core data for ID 5e9e28a1f359186d533b2638: Status code 525
# Error fetching core data for ID 5e9e28a1f35918233f3b2639: Status code 525
# Error fetching core data for ID 5e9e28a1f35918683c3b263a: Status code 525
# Error fetching core data for ID 5e9e28a1f3591867753b263b: Status code 525
# Error fetching core data for ID 5e9e28a1f3591842fa3b263c: Status code 525
# Error fetching core data for ID 5e9e28a1f359188def3b263d: Status code 525
# Error fetching core data for ID 5e9e28a2f359182d0b3b263e: Status code 525
# Error fetching core data for ID 5e9e28a2f35918077b3b263f: Status code 525
# Error fetching core data for ID 5e9e28a2f3591845c73b2640: Status code 525
# Error fetching core data for ID 5e9e28a2f359187f273b2642: Status code 525
# Error fetching core data for ID 5e9e28a2f35918b8243b2643: Status code 525
# Error fetching core data for ID 5e9e28a2f359187ee83b2644: Status code 525
# Error fetching core data for ID 5e9e28a3f359189e3a3b2645: Status code 525
# Error fetching core data for ID 5e9e28a3f3591829dc3b2646: Status code 525
# Error fetching core data for ID 5e9e28a3f3591878473b2647: Status code 525
# Error fetching core data for ID 5e9e28a2f359182d0b3b263e: Status code 525
# Error fetching core data for ID 5e9e28a3f3591811f83b2648: Status code 525
# Error fetching core data for ID 5e9e28a3f359186f3f3b2649: Status code 525
# Error fetching core data for ID 5e9e28a3f3591856803b264a: Status code 525
# Error fetching core data for ID 5e9e28a3f359189e3a3b2645: Status code 525
# Error fetching core data for ID 5e9e28a3f3591801cf3b264b: Status code 525
# Error fetching core data for ID 5e9e28a4f3591850cc3b264c: Status code 525
# Error fetching core data for ID 5e9e28a4f3591884ee3b264d: Status code 525
# Error fetching core data for ID 5e9e28a4f359182d843b264e: Status code 525
# Error fetching core data for ID 5e9e28a4f3591845123b264f: Status code 525
# Error fetching core data for ID 5e9e28a4f3591843103b2650: Status code 525
# Error fetching core data for ID 5e9e28a3f3591829dc3b2646: Status code 525
# Error fetching core data for ID 5e9e28a4f359185cc03b2651: Status code 525
# Error fetching core data for ID 5e9e28a3f3591856803b264a: Status code 525
# Error fetching core data for ID 5e9e28a3f3591801cf3b264b: Status code 525
# Error fetching core data for ID 5e9e28a4f35918345e3b2652: Status code 525
# Error fetching core data for ID 5e9e28a3f3591811f83b2648: Status code 525
# Error fetching core data for ID 5e9e28a5f359186cb73b2654: Status code 525
# Error fetching core data for ID 5e9e28a4f3591843103b2650: Status code 525
# Error fetching core data for ID 5e9e28a4f3591884ee3b264d: Status code 525
# Error fetching core data for ID 5e9e28a5f35918863d3b2655: Status code 525
# Error fetching core data for ID 5e9e28a5f359182b023b2656: Status code 525
# Error fetching core data for ID 5e9e28a4f3591845123b264f: Status code 525
# Error fetching core data for ID 5e9e28a5f35918863d3b2655: Status code 525
# Error fetching core data for ID 5e9e28a5f359181eed3b2657: Status code 525
# Error fetching core data for ID 5e9e28a5f3591809c03b2658: Status code 525
# Error fetching core data for ID 5e9e28a5f359182b023b2656: Status code 525
# Error fetching core data for ID 5e9e28a5f3591833b13b2659: Status code 525
# Error fetching core data for ID 5e9e28a5f3591809c03b2658: Status code 525
# Error fetching core data for ID 5e9e28a5f359181eed3b2657: Status code 525
# Error fetching core data for ID 5e9e28a5f359182b023b2656: Status code 525
# Error fetching core data for ID 5e9e28a6f359185c603b265a: Status code 525
# Error fetching core data for ID 5e9e28a6f35918513b3b265b: Status code 525
# Error fetching core data for ID 5e9e28a5f3591833b13b2659: Status code 525
# Error fetching core data for ID 5e9e28a6f35918c0803b265c: Status code 525
# Error fetching core data for ID 5e9e28a7f3591809313b2660: Status code 525
# Error fetching core data for ID 5e9e28a5f3591833b13b2659: Status code 525
# Error fetching core data for ID 5e9e28a6f35918c0803b265c: Status code 525
# Error fetching core data for ID 5e9e28a7f3591809313b2660: Status code 525
# Error fetching core data for ID 5e9e28a5f359181eed3b2657: Status code 525
# Error fetching core data for ID 5e9e28a5f3591809c03b2658: Status code 525
# Error fetching core data for ID 5e9e28a7f359187afd3b2662: Status code 525
# Error fetching core data for ID 5e9e28a7f3591809313b2660: Status code 525
# Error fetching core data for ID 5e9e28a5f3591833b13b2659: Status code 525
# Error fetching core data for ID 5e9e28a5f359182b023b2656: Status code 525
# Error fetching core data for ID 5e9e28a6f35918c0803b265c: Status code 525
# Error fetching core data for ID 5e9e28a7f3591809313b2660: Status code 525
# Error fetching core data for ID 5e9e28a7f359187afd3b2662: Status code 525
# Error fetching core data for ID 5e9e28a5f3591809c03b2658: Status code 525
# Error fetching core data for ID 5e9e28a6f35918c0803b265c: Status code 525
# Error fetching core data for ID 5e9e28a7f3591817f23b2663: Status code 525
# Error fetching core data for ID 5e9e28a5f3591833b13b2659: Status code 525
# Error fetching core data for ID 5e9e28a7f359187afd3b2662: Status code 525
# Error fetching core data for ID 5ef670f10059c33cee4a826c: Status code 525
# Error fetching core data for ID 5e9e28a7f3591817f23b2663: Status code 525
# Error fetching core data for ID 5e9e28a5f3591833b13b2659: Status code 525
# Error fetching core data for ID 5e9e28a7f359187afd3b2662: Status code 525
# Error fetching core data for ID 5ef670f10059c33cee4a826c: Status code 525
# Error fetching core data for ID 5e9e28a7f3591817f23b2663: Status code 525
# Error fetching core data for ID 5e9e28a6f35918c0803b265c: Status code 525
# Error fetching core data for ID 5ef670f10059c33cee4a826c: Status code 525
# Error fetching core data for ID 5f57c5440622a633027900a0: Status code 525

# %% [markdown]
# Finally lets construct our dataset using the data we have obtained. We we combine the columns into a dictionary.

# %%
launch_dict = {'FlightNumber': list(data['flight_number']),
'Date': list(data['date']),
'BoosterVersion':BoosterVersion,
'PayloadMass':PayloadMass,
'Orbit':Orbit,
'LaunchSite':LaunchSite,
'Outcome':Outcome,
'Flights':Flights,
'GridFins':GridFins,
'Reused':Reused,
'Legs':Legs,
'LandingPad':LandingPad,
'Block':Block,
'ReusedCount':ReusedCount,
'Serial':Serial,
'Longitude': Longitude,
'Latitude': Latitude}

# %% [markdown]
# Then, we need to create a Pandas data frame from the dictionary launch_dict.

# %%
df = pd.DataFrame(launch_dict)

# %% [markdown]
# Show the summary of the dataframe

# %%
# Show the head of the dataframe

# %% [markdown]
# ### Task 2: Filter the dataframe to only include `Falcon 9` launches

# %% [markdown]
# Finally we will remove the Falcon 1 launches keeping only the Falcon 9 launches. Filter the data dataframe using the <code>BoosterVersion</code> column to only keep the Falcon 9 launches. Save the filtered data to a new dataframe called <code>data_falcon9</code>.

# %%
data_falcon9 = df[df['BoosterVersion'] != 'Falcon 1']

# %% [markdown]
# Now that we have removed some values we should reset the FlgihtNumber column

# %%
data_falcon9.loc[:,'FlightNumber'] = list(range(1, data_falcon9.shape[0]+1))
data_falcon9
# Out:
#     FlightNumber        Date BoosterVersion PayloadMass Orbit LaunchSite  \
# 0              1  2006-03-24           None        None  None       None
# 1              2  2007-03-21           None        None  None       None
# 2              3  2008-09-28           None        None  None       None
# 3              4  2009-07-13           None        None  None       None
# 4              5  2010-06-04           None        None  None       None
# ..           ...         ...            ...         ...   ...        ...
# 89            90  2020-09-03           None        None  None       None
# 90            91  2020-10-06           None        None  None       None
# 91            92  2020-10-18           None        None  None       None
# 92            93  2020-10-24           None        None  None       None
# 93            94  2020-11-05           None        None  None       None
#
#       Outcome  Flights  GridFins  Reused   Legs                LandingPad  \
# 0   None None        1     False   False  False                      None
# 1   None None        1     False   False  False                      None
# 2   None None        1     False   False  False                      None
# 3   None None        1     False   False  False                      None
# 4   None None        1     False   False  False                      None
# ..        ...      ...       ...     ...    ...                       ...
# 89  True ASDS        2      True    True   True  5e9e3032383ecb6bb234e7ca
# 90  True ASDS        3      True    True   True  5e9e3032383ecb6bb234e7ca
# 91  True ASDS        6      True    True   True  5e9e3032383ecb6bb234e7ca
# 92  True ASDS        3      True    True   True  5e9e3033383ecbb9e534e7cc
# 93  True ASDS        1      True   False   True  5e9e3032383ecb6bb234e7ca
#
#    Block ReusedCount Serial Longitude Latitude
# 0   None        None   None      None     None
# 1   None        None   None      None     None
# 2   None        None   None      None     None
# 3   None        None   None      None     None
# 4   None        None   None      None     None
# ..   ...         ...    ...       ...      ...
# 89  None        None   None      None     None
# 90  None        None   None      None     None
# 91  None        None   None      None     None
# 92  None        None   None      None     None
# 93  None        None   None      None     None
#
# [94 rows x 17 columns]

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# We can see below that some of the rows are missing values in our dataset.

# %%
data_falcon9.isnull().sum()
# Out:
# FlightNumber       0
# Date               0
# BoosterVersion    94
# PayloadMass       94
# Orbit             94
# LaunchSite        94
# Outcome            0
# Flights            0
# GridFins           0
# Reused             0
# Legs               0
# LandingPad        30
# Block             94
# ReusedCount       94
# Serial            94
# Longitude         94
# Latitude          94
# dtype: int64

# %% [markdown]
# Before we can continue we must deal with these missing values. The <code>LandingPad</code> column will retain None values to represent when landing pads were not used.

# %% [markdown]
# ### Task 3: Dealing with Missing Values

# %% [markdown]
# Calculate below the mean for the <code>PayloadMass</code> using the <code>.mean()</code>. Then use the mean and the <code>.replace()</code> function to replace `np.nan` values in the data with the mean you calculated.

# %%
# Calculate the mean value of PayloadMass column

# Replace the np.nan values with its mean value

# %% [markdown]
# You should see the number of missing values of the <code>PayLoadMass</code> change to zero.

# %% [markdown]
# Now we should have no missing values in our dataset except for in <code>LandingPad</code>.

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section,but to make the answers consistent, in the next lab we will provide data in a pre-selected date range.

# %% [markdown]
# <code>data_falcon9.to_csv('dataset_part_1.csv', index=False)</code>

# %%
import requests

def make_api_call(url, params=None):
    """
    Makes a GET request to a specified URL and returns the JSON response.
    Includes basic error handling.
    """
    try:
        response = requests.get(url, params=params)
        response.raise_for_status() # Raise an HTTPError for bad responses (4xx or 5xx)
        return response.json()
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")  # Python 3.6+
    except requests.exceptions.ConnectionError as conn_err:
        print(f"Connection error occurred: {conn_err}")
    except requests.exceptions.Timeout as timeout_err:
        print(f"Timeout error occurred: {timeout_err}")
    except requests.exceptions.RequestException as req_err:
        print(f"An unexpected error occurred: {req_err}")
    return None

# Example usage with a placeholder API
example_url = "https://jsonplaceholder.typicode.com/posts/1"

print(f"\nMaking API call to: {example_url}")
json_data = make_api_call(example_url)

if json_data:
    print("API Call Successful! Data received:")
    print(json_data)
else:
    print("API Call Failed.")

# --- Flowchart Concept for API Calls ---
# Here's a conceptual flowchart breakdown for making an API call:
#
# 1. Start
# 2. Define API Endpoint (URL) and any parameters.
# 3. Initialize HTTP Request Library (e.g., 'requests' in Python).
# 4. Make HTTP Request (GET, POST, etc.) to the API Endpoint.
# 5. Check Response Status Code:
#    a. If 200 (OK): Proceed to parse data.
#    b. If 4xx (Client Error) or 5xx (Server Error): Handle error (e.g., log, retry, notify user).
# 6. Parse Response Data (e.g., JSON, XML).
# 7. Process Data (e.g., store in DataFrame, display, filter).
# 8. End
# Out:
# Making API call to: https://jsonplaceholder.typicode.com/posts/1
# API Call Successful! Data received:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# <!--## Change Log
# -->

# %% [markdown]
# <!--
#
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2020-09-20|1.1|Joseph|get result each time you run|
# |2020-09-20|1.1|Azim |Created Part 1 Lab using SpaceX API|
# |2020-09-20|1.0|Joseph |Modified Multiple Areas|
# -->

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
